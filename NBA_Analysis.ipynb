# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandeep-Bansal1/GA-JP/blob/main/NBA_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
df0
# Out:
#     Rk     G      Date     Age   Tm Unnamed: 5  Opp Unnamed: 7             GS  \
# 0    1   1.0  10/25/23  24-128  WAS          @  IND    L (-23)              1
# 1    2   2.0  10/28/23  24-131  WAS        NaN  MEM     W (+7)              1
# 2    3   3.0  10/30/23  24-133  WAS        NaN  BOS    L (-19)              1
# 3    4   4.0   11/1/23  24-135  WAS          @  ATL     L (-9)              1
# 4    5   5.0   11/3/23  24-137  WAS          @  MIA     L (-7)              1
# ..  ..   ...       ...     ...  ...        ...  ...        ...            ...
# 77  78  76.0    4/5/24  24-291  WAS        NaN  POR     L (-6)              1
# 78  79  77.0    4/7/24  24-293  WAS          @  TOR     L (-8)              1
# 79  80  78.0    4/9/24  24-295  WAS          @  MIN     L (-9)              1
# 80  81   NaN   4/12/24  24-298  WAS        NaN  CHI     L (-2)   Did Not Play
# 81  82   NaN   4/14/24  24-300  WAS          @  BOS    L (-10)  Did Not Dress
#
# ...

# %%
print(df['PTS'].mean())
print(df['TRB'].mean())
print(df['STL'].mean())
print(df['FG%'].mean())
print(df['3P%'].mean())
print(df['FT%'].mean())
# Out:
# 17.384615384615383
# 2.717948717948718
# 1.1025641025641026
# 0.39279487179487177
# 0.3009615384615385
# 0.8712459016393442

# %%
data = {
    'Statistic': ['PTS', 'TRB', 'STL', 'FG%', '3P%', 'FT%'],
    'Mean': [
        df0['PTS'].mean(),
        df0['TRB'].mean(),
        df0['STL'].mean(),
        df0['FG%'].mean(),
        df0['3P%'].mean(),
        df0['FT%'].mean()
    ]
}

# %%
mean_df = mean_df.sort_values(by='Mean', ascending=True)

# %%
# Creating a DataFrame for plotting
plt.figure(figsize=(12, 6))
bars = plt.barh(mean_df['Statistic'], mean_df['Mean'], color='skyblue')

# Adding the actual values on top of each bar
for bar in bars:
    xval = bar.get_width()

plt.xlabel('Mean Value')
plt.title('Jordan Poole Average 2023-2024')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Ensure the 'Date' column is in datetime format
df0['Date'] = pd.to_datetime(df0['Date'])

# Plotting the points per game over time with enhancements
plt.figure(figsize=(14, 7))

# Line plot with markers and a shaded area under the line
plt.plot(df0['Date'], df0['PTS'], marker='o', linestyle='-', color='darkgrey', linewidth=2, markersize=6)
plt.fill_between(df0['Date'], df0['PTS'], color='lightgrey', alpha=0.3)

# Adding annotations for peaks and valleys
max_idx = df0['PTS'].idxmax()
min_idx = df0['PTS'].idxmin()
plt.annotate(f'High: {df0["PTS"][max_idx]}', xy=(df0['Date'][max_idx], df0['PTS'][max_idx]),
             xytext=(df0['Date'][max_idx], df0['PTS'][max_idx] + 5),
             arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=12, color='black')
plt.annotate(f'Low: {df0["PTS"][min_idx]}', xy=(df0['Date'][min_idx], df0['PTS'][min_idx]),
             xytext=(df0['Date'][min_idx], df0['PTS'][min_idx] - 5),
             arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=12, color='black')

# Setting the x-axis to show dates more clearly
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

plt.xlabel('Date', fontsize=14)
plt.ylabel('Points per Game', fontsize=14)
plt.title('Points per Game Over Time - Jordan Poole (2003-2004)', fontsize=16, fontweight='bold')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
df1 = pd.read_csv('GilbertArenas.csv')

# %%
mean_pts = df1['PTS'].mean()
mean_trb = df1['TRB'].mean()
mean_stl = df1['STL'].mean()
mean_fg = df1['FG%'].mean()
mean_3p = df1['3P%'].mean()
mean_ft = df1['FT%'].mean()

# %%
data = {
    'Statistic': ['PTS', 'TRB', 'STL', 'FG%', '3P%', 'FT%'],
    'Mean': [mean_pts, mean_trb, mean_stl, mean_fg, mean_3p, mean_ft]
}

mean_df1 = pd.DataFrame(data)
mean_df1 = mean_df1.sort_values(by='Mean', ascending=True)

# %%
# Creating a DataFrame for plotting
plt.figure(figsize=(12, 6))
bars = plt.barh(mean_df1['Statistic'], mean_df1['Mean'], color='royalblue')

# Adding the actual values on top of each bar
for bar in bars:
    xval = bar.get_width()


plt.gca().invert_xaxis()  # Invert the x-axis to reverse the bar direction
plt.ylabel('Statistics')
plt.xlabel('Mean Value')
plt.title('Gilbert Arenas Average 2003-2004')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Ensure the 'Date' column is in datetime format
df1['Date'] = pd.to_datetime(df1['Date'])

# Plotting the points per game over time with enhancements
plt.figure(figsize=(14, 7))

# Line plot with markers and a shaded area under the line
plt.plot(df1['Date'], df1['PTS'], marker='o', linestyle='-', color='blue', linewidth=2, markersize=6)
plt.fill_between(df1['Date'], df1['PTS'], color='deepskyblue', alpha=0.3)

# Adding annotations for peaks and valleys
max_idx = df1['PTS'].idxmax()
min_idx = df1['PTS'].idxmin()
plt.annotate(f'High: {df1["PTS"][max_idx]}', xy=(df1['Date'][max_idx], df1['PTS'][max_idx]),
             xytext=(df['Date'][max_idx], df['PTS'][max_idx] + 5),
             arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=12, color='black')
plt.annotate(f'Low: {df1["PTS"][min_idx]}', xy=(df1['Date'][min_idx], df1['PTS'][min_idx]),
             xytext=(df1['Date'][min_idx], df1['PTS'][min_idx] - 5),
             arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=12, color='black')

# Setting the x-axis to show dates more clearly
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

plt.xlabel('Date', fontsize=14)
plt.ylabel('Points per Game', fontsize=14)
plt.title('Points per Game Over Time - Gilbert Arenas (2003-2004)', fontsize=16, fontweight='bold')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
df1.columns
# Out:
# Index(['Rk', 'G', 'Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
#        'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-'],
#       dtype='object')

# %%
df1['TOV'].sum()
# Out:
# 226.0

# %%
df0['TOV'].sum()
# Out:
# 188.0

# %%
result_df
# Out:
#            Player  TOV_Sum
# 0  Gilbert Arenas    226.0
# 1    Jordan Poole    188.0

# %%
import seaborn as sns

gilbert_arenas_tov_sum = df1['TOV'].sum()
jordan_poole_tov_sum = df0['TOV'].sum()

plt.figure(figsize=(12, 8))
sns.barplot(x='Player', y='TOV_Sum', data=result_df, palette='coolwarm')

# Adding titles and labels
plt.title('Total Turnovers in First Yr', fontsize=18, fontweight='bold')
plt.xlabel('Player', fontsize=14, fontweight='bold')
plt.ylabel('TOV_Sum', fontsize=14, fontweight='bold')

# Adding the exact values on top of the bars
for index, value in enumerate(df['Turnover Count']):
    plt.text(index, value + 0.5, str(value), ha='center', fontsize=12)

# Customizing the plot for better aesthetics
sns.despine(left=True, bottom=True)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()
# Out:
# <ipython-input-166-7bed6a3d082d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Player', y='TOV_Sum', data=result_df, palette='coolwarm')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df0['Date'] = pd.to_datetime(df0['Date'], errors='coerce')
df0['FT'] = pd.to_numeric(df0['FT'], errors='coerce')

# Drop rows with missing FT values and sort by date
df0 = df0.dropna(subset=['FT'])
df0 = df0.sort_values(by='Date')

# Plotting the time series chart with engaging features
plt.figure(figsize=(14, 8))

# Main plot
plt.plot(df0['Date'], df0['FT'], marker='o', linestyle='-', color='skyblue', linewidth=2)

# Adding a title and labels with enhanced font properties
plt.title('Number of Free Throws Jordan Poole Over Time', fontsize=20, fontweight='bold', color='navy')
plt.xlabel('Date', fontsize=16, fontweight='bold', color='navy')
plt.ylabel('Number of Free Throws (FT)', fontsize=16, fontweight='bold', color='navy')

# Adding grid and customizing it
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='black', alpha=0.7)

# Highlighting important dates
max_ft_date = df1.loc[df1['FT'].idxmax()]
plt.annotate(f"Max FT: {int(max_ft_date['FT'])}",
             xy=(max_ft_date['Date'], max_ft_date['FT']),
             xytext=(max_ft_date['Date'], max_ft_date['FT'] + 5),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=12, color='darkred')

# Adding a legend
plt.legend(['Free Throws (FT)'], loc='upper left', fontsize=12)

# Customizing the ticks
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Display the plot
plt.show()

# %%
df1['Date'] = pd.to_datetime(df1['Date'], errors='coerce')
df1['FT'] = pd.to_numeric(df1['FT'], errors='coerce')

# Drop rows with missing FT values and sort by date
df1 = df1.dropna(subset=['FT'])
df1 = df1.sort_values(by='Date')

# Plotting the time series chart with engaging features
plt.figure(figsize=(14, 8))

# Main plot
plt.plot(df1['Date'], df1['FT'], marker='o', linestyle='-', color='dodgerblue', linewidth=2)

# Adding a title and labels with enhanced font properties
plt.title('Number of Free Throws Gilbert Arenas Time', fontsize=20, fontweight='bold', color='navy')
plt.xlabel('Date', fontsize=16, fontweight='bold', color='navy')
plt.ylabel('Number of Free Throws (FT)', fontsize=16, fontweight='bold', color='navy')

# Adding grid and customizing it
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Highlighting important dates
max_ft_date = df1.loc[df1['FT'].idxmax()]
plt.annotate(f"Max FT: {int(max_ft_date['FT'])}",
             xy=(max_ft_date['Date'], max_ft_date['FT']),
             xytext=(max_ft_date['Date'], max_ft_date['FT'] + 5),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=12, color='darkred')

# Adding a legend
plt.legend(['Free Throws (FT)'], loc='upper left', fontsize=12)

# Customizing the ticks
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Display the plot
plt.show()

# %%
df0
# Out:
#     Rk     G       Date     Age   Tm Unnamed: 5  Opp Unnamed: 7 GS  MP    FG  \
# 0    1   1.0 2023-10-25  24-128  WAS          @  IND    L (-23)  1 NaN   7.0
# 1    2   2.0 2023-10-28  24-131  WAS        NaN  MEM     W (+7)  1 NaN   8.0
# 2    3   3.0 2023-10-30  24-133  WAS        NaN  BOS    L (-19)  1 NaN   5.0
# 3    4   4.0 2023-11-01  24-135  WAS          @  ATL     L (-9)  1 NaN   5.0
# 4    5   5.0 2023-11-03  24-137  WAS          @  MIA     L (-7)  1 NaN   8.0
# ..  ..   ...        ...     ...  ...        ...  ...        ... ..  ..   ...
# 75  76  74.0 2024-04-02  24-288  WAS        NaN  MIL     W (+4)  1 NaN   6.0
# 76  77  75.0 2024-04-03  24-289  WAS        NaN  LAL     L (-5)  1 NaN  10.0
# 77  78  76.0 2024-04-05  24-291  WAS        NaN  POR     L (-6)  1 NaN   8.0
# 78  79  77.0 2024-04-07  24-293  WAS          @  TOR     L (-8)  1 NaN  10.0
# 79  80  78.0 2024-04-09  24-295  WAS          @  MIN     L (-9)  1 NaN   9.0
#
# ...

# %%
JP_filtered_df = df0[df0['FT'] > 4]
JP_filtered_df.shape
# Out:
# (11, 30)

# %%
GA_filtered_df_FTA = df1[df1['FT'] > 4]
GA_filtered_df_FTA.shape
# Out:
# (24, 30)

# %%
data = {
    'Player': ['Jordan Poole', 'Gilbert Arenas'],
    'FTA > 4': [16, 31],
    'FT Made > 4': [11, 24]}

# %%
df_FT = pd.DataFrame(data)
df_FT

# %%
df_FT
# Out:
#            Player  FTA > 4  FT Made > 4
# 0    Jordan Poole       16           11
# 1  Gilbert Arenas       31           24

# %%
# Plot the stacked bar chart
ax = df_FT.plot(x='Player', kind='bar', stacked=True, color=['skyblue', 'lightblue'], edgecolor='grey', width=0.5, figsize=(14, 8))

# Set the title and labels
plt.title('Number of Free Throws Attempted and Made Over 4 by Player', fontsize=20, fontweight='bold')
plt.xlabel('Player', fontsize=14, fontweight='bold')
plt.ylabel('Count', fontsize=14, fontweight='bold')

# Add grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='white', alpha=0.7)

# Annotate the bars with the exact values
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height() + p.get_y()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points', fontsize=12, color='black')

# Add legend
plt.legend(title='FT Count', title_fontsize='13', fontsize='12')

# Customize the ticks
plt.xticks(rotation=0, fontsize=12, fontweight='bold')
plt.yticks(fontsize=12)

# Display the plot
plt.show()
